# %% [markdown]
# # Aprendendo notebook
#
#
# Introdução ao uso de notebooks da biblioteca pandas.

# %%
nome = 'Pedro'

print(nome)
# Out:
# Pedro

# %%
  # Dicionarios python 

aluno = {
    'nome':'Pedro' ,
    'matricula':'7777' ,
    'data_nascimento':'2006-03-13' 

}

aluno2 = {
    'nome':'Luciano' ,
    'matricula':'8888' ,
    'data_nascimento':'1096-05-19' 

}

print(aluno)
print(type(aluno))
print(aluno['nome'])
# Out:
# {'nome': 'Pedro', 'matricula': '7777', 'data_nascimento': '2006-03-13'}
# <class 'dict'>
# Pedro

# %%
alunos = [{
    'nome':'Pedro' ,
    'matricula':'7777' ,
    'data_nascimento':'2006-03-13' 

} ,

{
    'nome':'Luciano' ,
    'matricula':'8888' ,
    'data_nascimento':'1096-05-19' 

}]

print(alunos[1])
# Out:
# {'nome': 'Luciano', 'matricula': '8888', 'data_nascimento': '1096-05-19'}

# %%
frutas = [
    { 
        'nomes':['uva', 'laranja', 'maça', 'abacaxi'],
        'quantidade':[10, 15, 100, 0],
        'valor':[10.45, 5.99, 7.43 , 5.99]
    }
]

print(f"A fruta é {frutas[0]['nomes'][1]} com a quantidade {frutas[0]['quantidade'][1]} e o valor dela é {frutas[0]['valor'][1]}")
# Out:
# A fruta é laranja com a quantidade 15 e o valor dela é 5.99

# %% [markdown]
# ## Instalando bibliotecas no python
#
# Instala-se biblioteca python a estrutura:
#
# `pip install nome_bibliotecas`
#
# Site: `https://pypi.org/project/pandas/`

# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.7 MB 4.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.4/9.7 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.1/9.7 MB 4.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.2/9.7 MB 4.2 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.7 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 6.0/9.7 MB 4.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.8/9.7 MB 4.2 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.7 MB 4.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 4.2 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 4.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
frutas2 = ['uva', 'maça', 'laranja']

frutas3 = pd.Series(['uva', 'maça', 'laranja'])

print(type(frutas2))
print(type(frutas3))
# Out:
# <class 'list'>
# <class 'pandas.Series'>

# %%
display(frutas3)
# Out:
# 0        uva
# 1       maça
# 2    laranja
# dtype: str

# %%
df = pd.DataFrame ({
    'nome': ['uva', 'maça', 'laranja'],
    'quantidade': [10, 15, 20],
    'valor':[5.99, 3.50, 1.50],
    'data':['2026-04-02', '2026-03-13', '2026-06-22']
    })

display(df)
# Out:
#       nome  quantidade  valor        data
# 0      uva          10   5.99  2026-04-02
# 1     maça          15   3.50  2026-03-13
# 2  laranja          20   1.50  2026-06-22

# %%
display(df['data'])
# Out:
# 0    2026-04-02
# 1    2026-03-13
# 2    2026-06-22
# Name: data, dtype: str
